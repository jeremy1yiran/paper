# %%
import pandas as pd

data = pd.read_csv('data/out.csv')
data.head(5)
# Out:
#    is_increase  age Gender  Cellphone Education_Level Marital_Status consume  \
# 0            0    2      M          3               1        Married      32
# 1            0    2      F          5               2         Single      31
# 2            0    1      M          3               2        Married      33
# 3            0    3      F          4               1        Unknown      31
# 4            0    3      M          3               1        Married      32
#
#   Level  App
# 0  Blue    5
# 1  Blue    6
# 2  Blue    4
# 3  Blue    3
# 4  Blue    5

# %%
data.loc[(data['Marital_Status']=='Unknown'), 'Marital_Status'] = 'Married';

# %%
data.loc[(data['Education_Level']=='Unknown'), 'Education_Level'] = '2';

# %%
data.loc[(data['consume']=='Unknown'), 'consume'] = '32';

# %%
data.head(5)
# Out:
#    is_increase  age Gender  Cellphone Education_Level Marital_Status consume  \
# 0            0    2      M          3               1        Married      32
# 1            0    2      F          5               2         Single      31
# 2            0    1      M          3               2        Married      33
# 3            0    3      F          4               1        Married      31
# 4            0    3      M          3               1        Married      32
#
#   Level  App
# 0  Blue    5
# 1  Blue    6
# 2  Blue    4
# 3  Blue    3
# 4  Blue    5

# %%
def Education_Level(row):
    level = row['Level']
    education = row['Education_Level']
    
    
    if pd.isnull(pclass):
        return 'Unknow'
    elif pclass == 1:
        return 'First class'
    elif pclass == 2:
        return 'Second class'
    elif pclass == 3:
        return 'Third class'
classes = titanic.apply(which_class,axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-629ce3a88195> in <module>
#      12     elif pclass == 3:
#      13         return 'Third class'
# ---> 14 classes = titanic.apply(which_class,axis = 1)
#      15 classes
#
# NameError: name 'titanic' is not defined

# %%
data.head(20)
# Out:
#     is_increase  age Gender  Cellphone Education_Level Marital_Status consume  \
# 0             0    2      M          3               1        Married      32
# 1             0    2      F          5               2         Single      31
# 2             0    1      M          3               2        Married      33
# 3             0    3      F          4               1        Married      31
# 4             0    3      M          3               1        Married      32
# 5             0    2      M          2               2        Married      32
# 6             0    1      M          4               2        Married      33
# 7             0    3      M          0               1        Married      32
# 8             0    3      M          3               1         Single      32
# 9             0    2      M          2               2         Single      33
# 10            0    2      M          5               1        Married      33
# ...

# %%
import numpy as np

data_nun = data.replace(['Unknown'],np.nan)

# %%
data_nun.to_csv('./data/usersnan.csv')

# %%
data_nun.dropna(axis=0,how='any',thresh=None,subset=None,inplace=False).to_csv('./data/users1212.csv')

# %%
data_nun.head(100)
# Out:
#     is_increase  age Gender  Cellphone Education_Level Marital_Status consume  \
# 0             0    2      M          3               1        Married      32
# 1             0    2      F          5               2         Single      31
# 2             0    1      M          3               2        Married      33
# 3             0    3      F          4               1            NaN      31
# 4             0    3      M          3               1        Married      32
# ..          ...  ...    ...        ...             ...            ...     ...
# 95            0    6      M          1               2        Married      31
# 96            0    2      M          3               2        Married      32
# 97            0    1      M          3               3        Married      32
# 98            0    1      M          3               2        Married      33
# 99            1    2      M          2             NaN        Married      33
#
#    Level  App
# 0   Blue    5
# ...

# %%
data_nun.to_csv('./data/telcom_users_steam.csv')

# %%
data_nun.shape
# Out:
# (10127, 9)
